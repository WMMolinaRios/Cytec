# %%
import pandas as pd
import numpy as np
from os.path import dirname, basename, splitext, join
from glob import glob
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\wmolina\Desktop\GUI\200_HX-UHX.csv", delimiter=";", decimal=",", index_col='Parameter').fillna('')
df
# Out:
#                                   Modell Eisenverluste   Einheit      200HX  \
# Parameter
# B_l100                                  Blechpakethöhe        mm   100.0000
# D_l                               Drahtlänge pro Spule         m     9.3200
# Bmax       mag. Flussdichte in T             Vorläufig         T     1.7000
# VH                            Koeff. Hysterese in W/kg      W/kg     0.5780
# VW                          Koeff. Wirbelstrom in W/kg      W/kg     0.3170
# a                                 Exponent Wirbelstrom               1.6000
# b                                 Exponent Flussdichte               1.9300
# kb          Korrektur Blechdicke             Vorläufig               3.5000
# mb                                    Masse Blechpaket        kg     6.5200
# Rth                   thermischer Gesamtwiderstand H2O       K/W     0.0580
# Rwk               therm. Widerstand Wickelkopf Kühlung       K/W     0.5800
# Rwb                   therm. Widerstand Wicklung-Blech       K/W     0.0483
# Rbk                    therm. Widerstand Blech Kühlung       K/W     0.0161
# Rnk                  therm. Gesamtwiderstand ungekühlt       K/W     0.2088
# Cw                           therm. Kapazität Wicklung      Ws/K  1899.8000
# Cb                             therm. Kapazität Blech       Ws/K  3671.2000
# Tw                      therm. Zeitkonstanrte Wicklung         s    91.8000
# Tb                          therm. Zeitkonstante Blech         s    59.1000
# Cu                          spezifische Wärmekapazität  J/(kg*K)     0.3680
# mcu                                    cu gewicht ges.         g  4084.8500
# CW2243-2L                       Epoxid zwischen Spulen      g/mm     3.5088
# HY2966                          Härter zwischen Spulen      g/mm     0.4565
# c                           spezifische Wärmekapazität  J/(kg*K)     1.0000
# Want       Verhältnis Kupferanteile (Wickelkopfanteil)         %     0.2176
#
#               200UHX Unnamed: 5
# Parameter
# B_l100      100.0000
# D_l          21.3500
# Bmax          1.7000
# VH            0.5780
# VW            0.3170
# a             1.6000
# b             1.9300
# kb            3.5000
# mb            6.1300
# Rth           0.0580
# Rwk           0.5800
# Rwb           0.0483
# Rbk           0.0161
# Rnk           0.2088
# Cw         1623.5000
# Cb         3427.9000
# Tw           78.5000
# Tb           55.2000
# Cu            0.3680
# mcu        3435.4500
# CW2243-2L     3.1791
# HY2966        0.4136
# c             1.0000
# Want          0.1516

# %%
data2 = df["200UHX"]
data2
# Out:
# Parameter
# B_l100        100.0000
# D_l            21.3500
# Bmax            1.7000
# VH              0.5780
# VW              0.3170
# a               1.6000
# b               1.9300
# kb              3.5000
# mb              6.1300
# Rth             0.0580
# Rwk             0.5800
# Rwb             0.0483
# Rbk             0.0161
# Rnk             0.2088
# Cw           1623.5000
# Cb           3427.9000
# Tw             78.5000
# Tb             55.2000
# Cu              0.3680
# mcu          3435.4500
# CW2243-2L       3.1791
# HY2966          0.4136
# c               1.0000
# Want            0.1516
# Name: 200UHX, dtype: float64

# %%
Cw_200UHX = data2["Cu"]*data2["mcu"]+(data2["CW2243-2L"] + data2["HY2966"])*data2["B_l100"]*data2["c"]
Cw_200UHX
# Out:
# 1623.5156

# %%
Pvfe_200UHXkg = (data2['VH']*50+data2['VW']*(50)**data2['a'])*(data2['Bmax'])
Pvfe_200UHXkg
# Out:
# 330.87757744571866

# %%
Pfe_200UHX = (data2['kb']*data2['mb']*Pvfe_200UHXkg)
Pfe_200UHX
# Out:
# 7098.978424097893

# %%
Pcu_200UHX = (80*(data2["Rwk"]+data2["Rwb"]+data2["Rbk"])-data2["Rbk"]*Pfe_200UHX)/(data2["Rwk"]*(data2["Rwb"]+data2["Rbk"]))
Pcu_200UHX
# Out:
# -1679.7374338181648
